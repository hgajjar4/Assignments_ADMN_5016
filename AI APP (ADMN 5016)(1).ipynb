# %% [markdown]
# ### Project Name: T20 Score Prediction
# ### Presented By: Manthan Patel & Hetul Gajjar
# ### Subject Name: Artificial Intelligence And Machine Learing
# ### Professor Name: Joseph Santarcangelo

# %% [markdown]
# # About the company

# %% [markdown]
# PowerBlue is an analytical firm, which analyeses the data, and offers the best IT solutions to their clients to have the better understanding of their business accordingly. It includes creating, and deploying numerous Artificial Intelligence as well as Machine Learning models to automate the entire business process, and reduce the human error to achieve the very high level of accuracy with the business decisions in the favour of the organisation.

# %% [markdown]
# # Business Case

# %% [markdown]
# PowerBlue has received the project from its client, and he wants us to answer his following questions:
# 1. Analyse the given data on T20 International, and build a regression-based prediction model to predict what would be the final score on the baord at the end of the first innings.
# 2. Analyse whether each factor has any significant correlation with the total score on the board.
# 3. Recommend any possible ways out there to reduce the impact of possible negative impact on the team performance.

# %% [markdown]
# we can use this application for sports analysis like we can predict score, how batsman and bowler can perform, and how they can improve their mistake from past mistakes.Also, they can make a stategies against other team and players. teams can use this application for better performance
# we have simmilar application like this in market like fantasy cricket and dream 11 and Eagle Predict App and  many more.
#
# The global sports analytics market size was valued at approximately USD 1.9 billion in 2020 and is expected to reach USD 5.2 billion by 2026, growing at a CAGR of around 17.4% between 2021 and 2026.
# Within the sports analytics market, sports score prediction applications would be a subset of the overall market. Therefore, the exact market size for sports score prediction applications is likely to be smaller. However, with the increasing popularity of sports betting and the use of technology in sports, there may be a growing demand for such applications in the market

# %% [markdown]
# The monetary value and risks of a sports analysis application will depend on various factors such as the accuracy of the predictions, the size of the market, and the pricing model of the application.
# If the sports analysis application provides accurate predictions, it can be a valuable tool for individuals and businesses in the sports industry, such as sports teams, broadcasters, and sports betting companies. They can use the predictions to make informed decisions and potentially increase their revenue or profitability. For example, a sports team could use the predictions to improve their game strategy, which could lead to more wins and better ticket sales.
#
# On the other hand, if the predictions are inaccurate, the application may not provide any value, and users may be dissatisfied with the results, leading to negative reviews and a decline in revenue. Additionally, there may be legal risks associated with sports betting, and the application may need to comply with regulatory requirements, which can be costly.
# Regarding the amount of money that can be saved with a sports analysis application, it will depend on the specific use case and how the application is being used. For example, if a sports team is using the application to improve their game strategy and win more games, they could potentially earn more revenue from increased ticket sales and sponsorships. Similarly, if a sports betting company is using the application to make more accurate predictions, they could potentially increase their profitability.
#
# Overall, the monetary value and risks of a sports analysis application can vary significantly depending on various factors, and it's challenging to provide a specific answer without knowing more details about the application and its use case.

# %% [markdown]
# # Risks of Sports Analytics Application:

# %% [markdown]
# Inaccuracy: The accuracy of the predictions generated by sports analytics applications can vary, depending on the quality of the data and the algorithms used. Inaccurate predictions can lead to poor decision-making and negative outcomes, which can impact the reputation of the application and the organization using it.
#
# Privacy and security risks: Sports analytics applications may collect and store sensitive personal data, which can be at risk of cyberattacks and data breaches. This can have legal and reputational consequences, leading to fines, lawsuits, and loss of trust from customers and partners.
#
# Bias: Sports analytics applications can be biased if they are trained on data that is not representative of the entire population, leading to unfair and inaccurate predictions. This can have negative consequences for the sports teams and athletes using the application.
#
# Cost and complexity: Developing and implementing sports analytics applications can be expensive and time-consuming, requiring advanced technical skills, hardware, and software. This can be a barrier to entry for small and medium-sized organizations, limiting their ability to compete with larger organizations that have more resources.
#
# Overall, the risks and benefits of sports analytics applications depend on various factors, and organizations should carefully evaluate the potential risks and benefits before deciding to implement such applications.

# %% [markdown]
# # Benefits of Sports Analytics Application:

# %% [markdown]
# Improved performance: Sports analytics applications can provide insights and recommendations that can help sports teams and athletes improve their performance by identifying areas for improvement, optimizing training regimens, and developing better game strategies.
#
# Better decision-making: By providing accurate predictions and data-driven insights, sports analytics applications can help sports teams, broadcasters, and sports betting companies make more informed decisions about their strategies, investments, and game plans.
#
# Competitive advantage: By leveraging advanced analytics tools and techniques, sports analytics applications can help sports teams and organizations gain a competitive advantage over their competitors, leading to more wins, better player performance, and increased revenue.
#
# Fan engagement: Sports analytics applications can provide fans with real-time statistics and insights, creating a more engaging and immersive viewing experience. This can also help broadcasters and sports media companies generate more revenue from advertising and sponsorship deals.

# %%
# Import the important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from yaml import safe_load
import os
from tqdm import tqdm

# %%
#Convert the Yaml file to the Jason file
filenames = []
for file in os.listdir('Data'):
    filenames.append(os.path.join('Data',file))

# %%
filenames[0:5]
# Out:
# ['Data\\.ipynb_checkpoints',
#  'Data\\1001349.yaml',
#  'Data\\1001351.yaml',
#  'Data\\1001353.yaml',
#  'Data\\1004729.yaml']

# %%
#Load the dataset into the Dataframe from the Jason File
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    print(f"Processing file: {file}")
    try:
        with open(file, 'r') as f:
            df = pd.json_normalize(safe_load(f))
            df['match_id'] = counter
            final_df = final_df.append(df)
            counter += 1
    except Exception as e:
        print(f"Error processing file: {file} - {e}")

print(final_df.head())
# Out:
#   0%|                                                                                         | 0/1228 [00:00<?, ?it/s]C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3396459077.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
#   0%|▏                                                                                | 2/1228 [00:00<01:34, 12.92it/s]
# Processing file: Data\.ipynb_checkpoints
# Error processing file: Data\.ipynb_checkpoints - [Errno 13] Permission denied: 'Data\\.ipynb_checkpoints'
# Processing file: Data\1001349.yaml
# Processing file: Data\1001351.yaml
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3396459077.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(df)
# ...

# %%
# Create a backup file 
backup_df = final_df.copy()

# %% [markdown]
# # Load the dataset

# %%
# Call the dataframe
final_df
# Out:
#                                               innings  meta.data_version  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# ..                                                ...                ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...                0.9
# 0   [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...                0.9
#
#    meta.created  meta.revision    info.dates info.gender info.match_type  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Drop the unnecessary columns from the dataframe
final_df.drop(columns=[
    'meta.data_version',
    'meta.created',
    'meta.revision',
    'info.outcome.eliminator',
    'info.outcome.result',
    'info.outcome.method',
    'info.neutral_venue',
    'info.match_type_number',
    'info.outcome.by.runs',
    'info.outcome.by.wickets'
],inplace=True)

# %%
# Call the cleaned dataframe
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.gender info.match_type info.outcome.winner  info.overs  \
# 0         male             T20           Sri Lanka          20
# ...

# %%
# Check the counts of genderwise cricketers
final_df["info.gender"].value_counts()
# Out:
# male      770
# female    457
# Name: info.gender, dtype: int64

# %%
#Filter the dataframe that contains only Male Cricketers
final_df = final_df[final_df["info.gender"]=="male"]

# %%
#Drop one more column that contains genders of the cricketers
final_df.drop(columns=["info.gender"],inplace=True)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3146906393.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.drop(columns=["info.gender"],inplace=True)

# %%
# Call the filtered dataframe
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0              T20           Sri Lanka          20      [DAS Gunaratne]
# ...

# %%
# Check the counts of the type of the match
final_df["info.match_type"].value_counts()
# Out:
# T20    770
# Name: info.match_type, dtype: int64

# %%
# Check the counts of the total overs of the match (Per Innings)
final_df["info.overs"].value_counts()
# Out:
# 20    767
# 50      3
# Name: info.overs, dtype: int64

# %%
#Filter the data that contains only T20 Matches
final_df = final_df[final_df["info.overs"]==20]

# %%
# Call the dataframe
final_df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0              T20           Sri Lanka          20      [DAS Gunaratne]
# ...

# %%
# Save the data into pickle
import pickle
pickle.dump(final_df, open("data_level1.pkl", "wb"))

# %% [markdown]
# We do not need to read and load the Yaml data now since we have over data into the pickle. Henceforth, it is saved now and we can use the pickle file for our future analysis and encoding as well.

# %%
# Load the data from the pickle file
df = pickle.load(open("data_level1.pkl", "rb"))
df
# Out:
#                                               innings    info.dates  \
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 0   [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 0   [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ..                                                ...           ...
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 0   [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 0   [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 0   [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 0   [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#    info.match_type info.outcome.winner  info.overs info.player_of_match  \
# 0              T20           Sri Lanka          20      [DAS Gunaratne]
# ...

# %%
#Extract more data for the runs at each ball
matches = pickle.load(open('data_level1.pkl','rb'))
matches.iloc[0]['innings'][0]['1st innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.3: {'batsman': 'AJ Finch',
#    'bowler': 'SL Malinga',
#    'non_striker': 'M Klinger',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {0.4: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {0.5: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'M Klinger',
#    'bowler': 'SL Malinga',
#    'non_striker': 'AJ Finch',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {1.1: {'batsman': 'M Klinger',
#    'bowler': 'KMDN Kulasekara',
# ...

# %%
# Create a looop function to etract data per ball
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    if count in [75,108,150,180,268,360,443,458,584,748,982,1052,1111,1226,1345]:
        count+=1
        continue
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    delivery_df = delivery_df.append(loop_df)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\4172321232.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\4172321232.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\4172321232.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\4172321232.py:46: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   delivery_df = delivery_df.append(loop_df)
# ...

# %%
# Call the dataframe
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       768  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       768  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       768  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       768  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       768  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue
# ...

# %%
# Define a function to extract the bowling team
def bowl(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
# Create a column named bowling team in the dataframe
delivery_df["bowling_team"] = delivery_df.apply(bowl,axis=1)

# %%
# Call the dataframe
delivery_df
# Out:
#      match_id                   teams batting_team  ball          batsman  \
# 0           2  [Australia, Sri Lanka]    Australia   0.1         AJ Finch
# 1           2  [Australia, Sri Lanka]    Australia   0.2         AJ Finch
# 2           2  [Australia, Sri Lanka]    Australia   0.3         AJ Finch
# 3           2  [Australia, Sri Lanka]    Australia   0.4        M Klinger
# 4           2  [Australia, Sri Lanka]    Australia   0.5        M Klinger
# ..        ...                     ...          ...   ...              ...
# 121       768  [Sri Lanka, Australia]    Sri Lanka  19.3  SMSM Senanayake
# 122       768  [Sri Lanka, Australia]    Sri Lanka  19.4      DM de Silva
# 123       768  [Sri Lanka, Australia]    Sri Lanka  19.5      DM de Silva
# 124       768  [Sri Lanka, Australia]    Sri Lanka  19.6  SMSM Senanayake
# 125       768  [Sri Lanka, Australia]    Sri Lanka  19.7  SMSM Senanayake
#
#          bowler  runs player_dismissed     city                     venue  \
# ...

# %%
# Drop the teams columns from the dataframe
delivery_df.drop(columns=["teams"],inplace=True)

# %%
# Call the dataframe
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       768    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       768    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       768    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       768    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       768    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
# Check the unique teams in the dataframe
delivery_df["batting_team"].unique()
# Out:
# array(['Australia', 'Hong Kong', 'Zimbabwe', 'India', 'Bangladesh',
#        'New Zealand', 'South Africa', 'England', 'West Indies', 'Ireland',
#        'Afghanistan', 'Pakistan', 'United Arab Emirates', 'Scotland',
#        'Oman', 'Papua New Guinea', 'Sri Lanka', 'Netherlands', 'Nepal',
#        'Vanuatu', 'Philippines', 'United States of America', 'Germany',
#        'Ghana', 'Uganda', 'Kenya', 'Namibia', 'Nigeria', 'Botswana',
#        'Guernsey', 'Denmark', 'Jersey', 'Italy', 'Norway', 'Thailand',
#        'Malaysia', 'Maldives', 'Singapore', 'Kuwait', 'Bermuda', 'Canada',
#        'Cayman Islands', 'Portugal', 'Gibraltar', 'Spain', 'Bhutan',
#        'Qatar', 'Iran', 'Belgium', 'Isle of Man', 'Bulgaria', 'Romania'],
#       dtype=object)

# %%
# Create a list of the consistent teams
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Afghanistan',
    'Pakistan',
    'Sri Lanka'    
]

# %%
# Filter the dataframe that contains only the consistent teams
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
# Call the dataframe
delivery_df
# Out:
#      match_id batting_team  ball          batsman      bowler  runs  \
# 0           2    Australia   0.1         AJ Finch  SL Malinga     0
# 1           2    Australia   0.2         AJ Finch  SL Malinga     0
# 2           2    Australia   0.3         AJ Finch  SL Malinga     1
# 3           2    Australia   0.4        M Klinger  SL Malinga     2
# 4           2    Australia   0.5        M Klinger  SL Malinga     0
# ..        ...          ...   ...              ...         ...   ...
# 121       768    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 122       768    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 123       768    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 124       768    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 125       768    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
#     player_dismissed     city                     venue bowling_team
# 0                  0      NaN  Melbourne Cricket Ground    Sri Lanka
# ...

# %%
# Create a new dataframe by removing some columns from the the current one
output = delivery_df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
# Call the new dataframe
output
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       768    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       768    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       768    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       768    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %%
# Save the dataset into the pickle format
pickle.dump(output,open("data_level2.pkl","wb"))

# %%
# Load the dataset
df = pickle.load(open('data_level2.pkl','rb'))

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       768    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       768    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       768    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       768    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# ...

# %% [markdown]
# As of now we have 8 featuresare in total, but we need some more features to predict the score accurately. We would also have to remove certain existing features since they are unnecessary while building the model

# %% [markdown]
# #### The required features are as follows:
# 1. Batting Team
# 2. Bowling Team
# 3. Current Score
# 4. Wickets Left
# 5. Current Run Rate
# 6. City
# 7. Balls left
# 8. Last FIve Overs Runs

# %%
# Create a City Feature
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                6480
# venue                  0
# dtype: int64

# %%
# Check for the counts of Venue where City is Null
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# Dubai International Cricket Stadium        2476
# Pallekele International Cricket Stadium    1569
# Melbourne Cricket Ground                    866
# Sydney Cricket Ground                       380
# Adelaide Oval                               376
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: venue, dtype: int64

# %% [markdown]
# Henceforth, we can say that there is a problem, but we could fix the problem of city value,, if we could extract some insights from venue.

# %%
# Extract the first word of Venue, where the City value is null
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
# Split the words in Venue
df['venue'].str.split()
# Out:
# 0      [Melbourne, Cricket, Ground]
# 1      [Melbourne, Cricket, Ground]
# 2      [Melbourne, Cricket, Ground]
# 3      [Melbourne, Cricket, Ground]
# 4      [Melbourne, Cricket, Ground]
#                    ...
# 121         [R, Premadasa, Stadium]
# 122         [R, Premadasa, Stadium]
# 123         [R, Premadasa, Stadium]
# 124         [R, Premadasa, Stadium]
# 125         [R, Premadasa, Stadium]
# Name: venue, Length: 44879, dtype: object

# %%
# Extract the first word of Venue, where the City value is null
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
# Fill the values of cities column to city column
df["city"] = cities

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city                     venue
# 0    Melbourne  Melbourne Cricket Ground
# 1    Melbourne  Melbourne Cricket Ground
# ...

# %%
# Check for missing values in cities column
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
# Drop the venue column
df.drop(columns=["venue"],inplace=True)

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
# Create a variable that contains only the consistent cities 
cons_city = df['city'].value_counts()[df['city'].value_counts() > 600].index
cons_city
# Out:
# Index(['Colombo', 'Mirpur', 'Dubai', 'Auckland', 'Pallekele', 'Cape Town',
#        'Johannesburg', 'Sydney', 'Lauderhill', 'Melbourne', 'Centurion',
#        'Mount Maunganui', 'Mumbai', 'Chittagong', 'Wellington', 'Abu Dhabi',
#        'Manchester', 'Lahore', 'Hamilton', 'Delhi', 'Southampton', 'Kolkata',
#        'Durban', 'Bangalore', 'Nagpur', 'Barbados'],
#       dtype='object')

# %%
# Conver the consistent cities into a list
cons_city = cons_city.tolist()

# %%
cons_city
# Out:
# ['Colombo',
#  'Mirpur',
#  'Dubai',
#  'Auckland',
#  'Pallekele',
#  'Cape Town',
#  'Johannesburg',
#  'Sydney',
#  'Lauderhill',
#  'Melbourne',
#  'Centurion',
#  'Mount Maunganui',
#  'Mumbai',
#  'Chittagong',
#  'Wellington',
#  'Abu Dhabi',
#  'Manchester',
#  'Lahore',
#  'Hamilton',
#  'Delhi',
#  'Southampton',
#  'Kolkata',
#  'Durban',
#  'Bangalore',
#  'Nagpur',
#  'Barbados']

# %%
# Filter the dataframe that contains only the consistent cities
df = df[df['city'].isin(cons_city)]

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# ...

# %%
# Create a feature current score into the dataframe
df["current_score"] = df.groupby("match_id").cumsum()["runs"]
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1657253153.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.cumsum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df["current_score"] = df.groupby("match_id").cumsum()["runs"]
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1657253153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["current_score"] = df.groupby("match_id").cumsum()["runs"]

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# ...

# %%
# Etract more insights from the balls columns
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3880676974.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3880676974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])

# %%
# Call the dataframre
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# ...

# %%
# Create a column to count the bowled numbers
df["balls_bowled"] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1563941927.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["balls_bowled"] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# ...

# %%
# Create a column into the dataframe that contains the nukmber of balls are left for the match
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3794437474.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3794437474.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       768    Sri Lanka    Australia  19.3     1                0
# 122       768    Sri Lanka    Australia  19.4     0                0
# 123       768    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       768    Sri Lanka    Australia  19.6     2                0
# 125       768    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# ...

# %%
# Convert the catagorical data into numerical 
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
# Get the count of the number of wickets fallen
df['player_dismissed'] = df.groupby('match_id').cumsum()['player_dismissed']
# Create a columns into the dataframe that contains the number of wickets left
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\163688075.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\163688075.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# ...

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       768    Sri Lanka    Australia  19.3     1                 8
# 122       768    Sri Lanka    Australia  19.4     0                 8
# 123       768    Sri Lanka    Australia  19.5     0                 9
# 124       768    Sri Lanka    Australia  19.6     2                 9
# 125       768    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# Create a feature current run rate into the dataframe
df["crr"] = (df["current_score"]*6)/df["balls_bowled"]
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1635106054.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["crr"] = (df["current_score"]*6)/df["balls_bowled"]

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       768    Sri Lanka    Australia  19.3     1                 8
# 122       768    Sri Lanka    Australia  19.4     0                 8
# 123       768    Sri Lanka    Australia  19.5     0                 9
# 124       768    Sri Lanka    Australia  19.6     2                 9
# 125       768    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# Create a feature last 5 over runs scored by the team into the dataframe 
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\2239694375.py:7: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['batting_team', 'bowling_team', 'city'], dtype='object')
#   last_five.extend(groups.get_group(id).rolling(window=30).sum()['runs'].values.tolist())

# %%
# Create a feature last 5 over runs scored by the team into the dataframe 
df["last_five"] = last_five
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\972126735.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["last_five"] = last_five

# %%
# Call the dataframe
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       768    Sri Lanka    Australia  19.3     1                 8
# 122       768    Sri Lanka    Australia  19.4     0                 8
# 123       768    Sri Lanka    Australia  19.5     0                 9
# 124       768    Sri Lanka    Australia  19.6     2                 9
# 125       768    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
# Calculate the total runs
df.groupby("match_id").sum()["runs"]
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1806623711.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("match_id").sum()["runs"]
# match_id
# 2      168
# 10     195
# 11     194
# 12     185
# 13     142
#       ...
# 762    129
# 764    150
# 765    120
# 767    263
# 768    128
# Name: runs, Length: 253, dtype: int64

# %%
# Reset the index
df.groupby("match_id").sum()["runs"].reset_index()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3988197138.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("match_id").sum()["runs"].reset_index()
#      match_id  runs
# 0           2   168
# 1          10   195
# 2          11   194
# 3          12   185
# 4          13   142
# ..        ...   ...
# 248       762   129
# 249       764   150
# 250       765   120
# 251       767   263
# 252       768   128
#
# [253 rows x 2 columns]

# %%
# Merge the dataframe
# runs_x: Total Score
# runs_y: Score on the particular ball
df.groupby("match_id").sum()["runs"].reset_index().merge(df,on="match_id")
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1086968566.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("match_id").sum()["runs"].reset_index().merge(df,on="match_id")
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 30720       768     128    Sri Lanka    Australia  19.3       1
# 30721       768     128    Sri Lanka    Australia  19.4       0
# ...

# %%
# Save into the final dataframe
final_df = df.groupby("match_id").sum()["runs"].reset_index().merge(df,on="match_id")
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3269312578.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   final_df = df.groupby("match_id").sum()["runs"].reset_index().merge(df,on="match_id")

# %%
# Call the final dataframe
final_df
# Out:
#        match_id  runs_x batting_team bowling_team  ball  runs_y  \
# 0             2     168    Australia    Sri Lanka   0.1       0
# 1             2     168    Australia    Sri Lanka   0.2       0
# 2             2     168    Australia    Sri Lanka   0.3       1
# 3             2     168    Australia    Sri Lanka   0.4       2
# 4             2     168    Australia    Sri Lanka   0.5       0
# ...         ...     ...          ...          ...   ...     ...
# 30720       768     128    Sri Lanka    Australia  19.3       1
# 30721       768     128    Sri Lanka    Australia  19.4       0
# 30722       768     128    Sri Lanka    Australia  19.5       0
# 30723       768     128    Sri Lanka    Australia  19.6       2
# 30724       768     128    Sri Lanka    Australia  19.7       1
#
#        player_dismissed       city  current_score over ball_no  balls_bowled  \
# 0                     0  Melbourne              0    0       1             1
# ...

# %%
# Extract only important columns from the dataframe
final_df = final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
# Call the dataframe
final_df
# Out:
#       batting_team bowling_team       city  current_score  balls_left  \
# 0        Australia    Sri Lanka  Melbourne              0         119
# 1        Australia    Sri Lanka  Melbourne              0         118
# 2        Australia    Sri Lanka  Melbourne              1         117
# 3        Australia    Sri Lanka  Melbourne              3         116
# 4        Australia    Sri Lanka  Melbourne              3         115
# ...            ...          ...        ...            ...         ...
# 30720    Sri Lanka    Australia    Colombo            125           3
# 30721    Sri Lanka    Australia    Colombo            125           2
# 30722    Sri Lanka    Australia    Colombo            125           1
# 30723    Sri Lanka    Australia    Colombo            127           0
# 30724    Sri Lanka    Australia    Colombo            128           0
#
#        wickets_left       crr  last_five  runs_x
# 0                10  0.000000        NaN     168
# ...

# %% [markdown]
# # Missing Values

# %%
# Check the missing values
final_df.isnull().sum()
# Out:
# batting_team        0
# bowling_team        0
# city                0
# current_score       0
# balls_left          0
# wickets_left        0
# crr                 0
# last_five        7324
# runs_x              0
# dtype: int64

# %%
# Remove the missing values from the dataframe
final_df.dropna(inplace=True)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\3729918211.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.dropna(inplace=True)

# %%
# Check for the missing values
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
# Shuffle the data
final_df = final_df.sample(final_df.shape[0])

# %%
# Call the dataframe
final_df
# Out:
#        batting_team  bowling_team          city  current_score  balls_left  \
# 18049     Sri Lanka    Bangladesh     Pallekele            166          14
# 8366      Australia  South Africa  Johannesburg             62          89
# 16580      Pakistan  South Africa     Centurion            132          44
# 17289     Australia      Pakistan         Dubai             88          67
# 29131   Afghanistan   West Indies        Nagpur             66          36
# ...             ...           ...           ...            ...         ...
# 15677  South Africa         India  Johannesburg             56          83
# 17885         India      Pakistan     Bangalore             83          48
# 11182    Bangladesh      Pakistan        Lahore             71          54
# 19498   New Zealand   West Indies      Auckland             41          91
# 7113       Pakistan     Australia     Abu Dhabi            128          22
#
#        wickets_left        crr  last_five  runs_x
# ...

# %%
pickle.dump(final_df, open("data_level3.pkl", "wb"))

# %%
# Import Sci-kit learn libraries
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from statistics import mean

# %%
# One Hot Encoding to transform the catagorical data to numerical data
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
# Label Encoding
le = LabelEncoder()
label = le.fit_transform(final_df[['batting_team']])
#label- Batting
final_df.drop("batting_team", axis= 1, inplace=True)
final_df["batting_team"] = label
label_bt = le.fit_transform(final_df[['batting_team']])
#label- Bowling
final_df.drop("bowling_team", axis= 1, inplace=True)
final_df["bowling_team"] = label
label_bl = le.fit_transform(final_df[['bowling_team']])
#label - City
final_df.drop("city", axis= 1, inplace=True)
final_df["city"] = label
label_ct= le.fit_transform(final_df[['city']])
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\patel\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\patel\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
# Call the dataframe
final_df
# Out:
#        current_score  balls_left  wickets_left        crr  last_five  runs_x  \
# 18049            166          14             6   9.396226       58.0     198
# 8366              62          89             9  12.000000       58.0     196
# 16580            132          44             8  10.421053       62.0     195
# 17289             88          67            10   9.962264       59.0     168
# 29131             66          36             5   4.714286       22.0     123
# ...              ...         ...           ...        ...        ...     ...
# 15677             56          83             9   9.081081       38.0     219
# 17885             83          48             9   6.916667       33.0     133
# 11182             71          54             9   6.454545       34.0     141
# 19498             41          91             9   8.482759       41.0     189
# 7113             128          22             7   7.836735       42.0     155
#
#        batting_team  bowling_team  city
# ...

# %% [markdown]
# # Split the data

# %%
x = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=51)

# %%
# Print the train data
x_train
# Out:
#        current_score  balls_left  wickets_left        crr  last_five  \
# 21535             94          35             6   6.635294       38.0
# 18104             25          81             7   3.846154       18.0
# 11603            168          11             8   9.247706       51.0
# 30676             76          43             4   5.922078       23.0
# 8399              99          61             8  10.067797       33.0
# ...              ...         ...           ...        ...        ...
# 74                90          46             8   7.297297       36.0
# 11324             84          36             7   6.000000       39.0
# 1304              79          57             8   7.523810       40.0
# 24672            173           1             3   8.722689       40.0
# 25384            123          31             7   8.292135       36.0
#
#        batting_team  bowling_team  city
# 21535             4             4     4
# 18104             7             7     7
# ...

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
])

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()
model1.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_pred = model1.predict(x_train)

# %%
print('Train RMSE:', np.sqrt(metrics.mean_squared_error(y_train, lr_pred)))
# Out:
# Train RMSE: 18.997816978873473

# %%
predict1=model1.predict(x_test)

# %%
sns.distplot(y_test-predict1)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\1632519303.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predict1)
# <Axes: xlabel='runs_x', ylabel='Density'>

# %%
from sklearn.metrics import r2_score
lr_accuracy = r2_score(y_test,predict1)
print(lr_accuracy)
# Out:
# 0.652322893891994

# %%
print(f"The Model Accuracy is {lr_accuracy}.")
# Out:
# The Model Accuracy is 0.652322893891994.

# %% [markdown]
# # XGBOOST Regression

# %%
from xgboost import XGBRegressor
model2 = XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1)
model2.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.2, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=12, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=1, ...)

# %%
xgb_pred = model2.predict(x_train)

# %%
print('Train RMSE:', np.sqrt(metrics.mean_squared_error(y_train, xgb_pred)))
# Out:
# Train RMSE: 1.3371736624916921

# %%
predict2=model2.predict(x_test)

# %%
sns.distplot(y_test-predict2)
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_21104\4025396619.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-predict2)
# <Axes: xlabel='runs_x', ylabel='Density'>

# %%
from sklearn.metrics import r2_score
xgb_accuracy = r2_score(y_test,predict2)
print(f"The Model Accuracy is {xgb_accuracy}.")
# Out:
# The Model Accuracy is 0.8795589991575656.

# %%
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
import xgboost
xgboost.__version__
# Out:
# '1.7.5'
